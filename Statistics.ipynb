# %% [markdown]
# ### Fitting distributions

# %%
# Iterate over each group
for name, group in combined_df.groupby(['Zonkod', 'Tidpunkt']):
    print("Fitting distributions for group:", name)
    
    # Extract data from the group
    data = group['Tid_i_minuter']
    
    # Remove non-finite values
    data = data.dropna()  # Remove NaN values
    data = data[np.isfinite(data)]  # Remove infinite values
    
    if len(data) == 0:
        print("No valid data for fitting distributions.")
        continue
    
    # Fit lognormal distribution
    if 'lognorm' in distributions:
        sigma, loc, scale = stats.lognorm.fit(data)
        print("Lognormal distribution parameters:", sigma, loc, scale)
    
    # Fit gamma distribution
    if 'gamma' in distributions:
        shape, loc, scale = stats.gamma.fit(data)
        print("Gamma distribution parameters:", shape, loc, scale)
    
    # Fit beta distribution
    if 'beta' in distributions:
        a, b, loc, scale = stats.beta.fit(data)
        print("Beta distribution parameters:", a, b, loc, scale)
# Out:
# Fitting distributions for group: ('0', 'night')
# No valid data for fitting distributions.
# Fitting distributions for group: ('0', 'morning')
# No valid data for fitting distributions.
# Fitting distributions for group: ('0', 'lunch')
# No valid data for fitting distributions.
# Fitting distributions for group: ('0', 'morning_sat')
# No valid data for fitting distributions.
# Fitting distributions for group: ('0', 'afternoon')
# No valid data for fitting distributions.
# Fitting distributions for group: ('0', 'evening')
# No valid data for fitting distributions.
# Fitting distributions for group: ('0', 'sunday')
# No valid data for fitting distributions.
# Fitting distributions for group: ('0', 'afternoon_sat')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1001', 'night')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1001', 'morning')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1001', 'lunch')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1001', 'morning_sat')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1001', 'afternoon')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1001', 'evening')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1001', 'sunday')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1001', 'afternoon_sat')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1002', 'night')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1002', 'morning')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1002', 'lunch')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1002', 'morning_sat')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1002', 'afternoon')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1002', 'evening')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1002', 'sunday')
# No valid data for fitting distributions.
# Fitting distributions for group: ('1002', 'afternoon_sat')
# No valid data for fitting distributions.
# Fitting distributions for group: ('25437000111', 'morning')
# Lognormal distribution parameters: 2.3818820251011297 2.633333333333333 4.379334386397856e-16
# ---------------------------------------------------------------------------
# FitError                                  Traceback (most recent call last)
# Cell In[1067], line 23
#      21 # Fit gamma distribution
#      22 if 'gamma' in distributions:
# ---> 23     shape, loc, scale = stats.gamma.fit(data)
#      24     print("Gamma distribution parameters:", shape, loc, scale)
#      26 # Fit beta distribution
#
# File c:\Users\ilts\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_continuous_distns.py:3400, in gamma_gen.fit(self, data, *args, **kwds)
#    3394 method = kwds.get('method', 'mle')
#    3396 if (isinstance(data, CensoredData) or
#    3397         floc is None and method.lower() != 'mm'):
#    3398     # loc is not fixed or we're not doing standard MLE.
#    3399     # Use the default fit method.
# -> 3400     return super().fit(data, *args, **kwds)
#    3402 # We already have this value, so just pop it from kwds.
#    3403 kwds.pop('floc', None)
#
# File c:\Users\ilts\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2691, in rv_continuous.fit(self, data, *args, **kwds)
#    2689 loc, scale, shapes = self._unpack_loc_scale(vals)
#    2690 if not (np.all(self._argcheck(*shapes)) and scale > 0):
# -> 2691     raise FitError("Optimization converged to parameters that are "
#    2692                    "outside the range allowed by the distribution.")
#    2694 if method == 'mm':
#    2695     if not np.isfinite(obj):
#
# FitError: Optimization converged to parameters that are outside the range allowed by the distribution.

# %%
# Define lists to store the evaluation results for each distribution
lognormal_results = []
gamma_results = []
beta_results = []

# Loop through each group of data
for group_name, group_data in combined_df.groupby(['Zonkod', 'Tidpunkt']):
    print(f"Evaluating distribution for group: {group_name}")
    
    # Extract data for the current group
    data = group_data['Tid_i_minuter']
    
    # Check if the data is valid for fitting distributions
    if len(data) > 1:
        # Fit lognormal distribution if valid data is available
        try:
            sigma, loc, scale = stats.lognorm.fit(data)
            lognormal_test = stats.kstest(data, stats.lognorm.cdf, args=(sigma, loc, scale))
            lognormal_results.append((group_name, sigma, loc, scale, lognormal_test))
        except:
            print("No valid data for lognormal distribution.")
        
        # Fit gamma distribution if valid data is available
        try:
            shape, loc, scale = stats.gamma.fit(data)
            gamma_test = stats.kstest(data, stats.gamma.cdf, args=(shape, loc, scale))
            gamma_results.append((group_name, shape, loc, scale, gamma_test))
        except:
            print("No valid data for gamma distribution.")
        
        # Fit beta distribution if valid data is available
        try:
            a, b, loc, scale = stats.beta.fit(data)
            beta_test = stats.kstest(data, stats.beta.cdf, args=(a, b, loc, scale))
            beta_results.append((group_name, a, b, loc, scale, beta_test))
        except:
            print("No valid data for beta distribution.")
    else:
        print("Insufficient data for fitting distributions.")
if lognormal_test.statistic < gamma_test.statistic and lognormal_test.statistic < beta_test.statistic:
    print("Lognormal distribution is the best fit.")
elif gamma_test.statistic < lognormal_test.statistic and gamma_test.statistic < beta_test.statistic:
    print("Gamma distribution is the best fit.")
else:
    print("Beta distribution is the best fit.")
# Out:
# Evaluating distribution for group: ('0', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('0', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('0', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('0', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('0', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('0', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('0', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('0', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1001', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1001', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1001', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1001', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1001', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1001', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1001', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1001', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1002', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1002', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1002', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1002', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1002', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1002', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1002', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('1002', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('25437000111', 'morning')
# Insufficient data for fitting distributions.
# Evaluating distribution for group: ('25437000111', 'lunch')
# Evaluating distribution for group: ('25437000111', 'morning_sat')
# Evaluating distribution for group: ('25437000111', 'afternoon')
# Evaluating distribution for group: ('25437000111', 'sunday')
# Evaluating distribution for group: ('25437000111', 'afternoon_sat')
# Evaluating distribution for group: ('42001', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42001', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42001', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42001', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42001', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42001', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42001', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42001', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42002', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42002', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42002', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42002', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42002', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42002', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42002', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42002', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42003', 'night')
# Evaluating distribution for group: ('42003', 'morning')
# Evaluating distribution for group: ('42003', 'lunch')
# Evaluating distribution for group: ('42003', 'morning_sat')
# Evaluating distribution for group: ('42003', 'afternoon')
# Evaluating distribution for group: ('42003', 'evening')
# Evaluating distribution for group: ('42003', 'sunday')
# Evaluating distribution for group: ('42003', 'afternoon_sat')
# Evaluating distribution for group: ('42004', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42004', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42004', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42004', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42004', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42004', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42004', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42004', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42006', 'night')
# Evaluating distribution for group: ('42006', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42006', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42006', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42006', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42006', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42006', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42006', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42007', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42007', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42007', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42007', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42007', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42007', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42007', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42007', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42010', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42010', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42010', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42010', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42010', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42010', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42010', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42010', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42012', 'night')
# Evaluating distribution for group: ('42012', 'morning')
# Evaluating distribution for group: ('42012', 'lunch')
# Evaluating distribution for group: ('42012', 'morning_sat')
# Evaluating distribution for group: ('42012', 'afternoon')
# Evaluating distribution for group: ('42012', 'evening')
# Evaluating distribution for group: ('42012', 'sunday')
# Evaluating distribution for group: ('42012', 'afternoon_sat')
# Evaluating distribution for group: ('42013', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42013', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42013', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42013', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42013', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42013', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42013', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42013', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42014', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42014', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42014', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42014', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42014', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42014', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42014', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42014', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42015', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42015', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42015', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42015', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42015', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42015', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42015', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42015', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42016', 'night')
# Insufficient data for fitting distributions.
# Evaluating distribution for group: ('42016', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42016', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42016', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42016', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42016', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42016', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42016', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('420160', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('420160', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('420160', 'morning_sat')
# Insufficient data for fitting distributions.
# Evaluating distribution for group: ('420160', 'afternoon')
# Insufficient data for fitting distributions.
# Evaluating distribution for group: ('420160', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('420160', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42017', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42017', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42017', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42017', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42017', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42017', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42017', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42017', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42019', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42019', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42019', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42019', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42019', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42019', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42019', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42019', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42020', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42020', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42020', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42020', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42020', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42020', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42020', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42020', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42022', 'night')
# Evaluating distribution for group: ('42022', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42022', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42022', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42022', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42022', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42022', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42022', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42024', 'night')
# Evaluating distribution for group: ('42024', 'morning')
# Evaluating distribution for group: ('42024', 'lunch')
# Evaluating distribution for group: ('42024', 'morning_sat')
# Evaluating distribution for group: ('42024', 'afternoon')
# Evaluating distribution for group: ('42024', 'evening')
# Evaluating distribution for group: ('42024', 'sunday')
# Evaluating distribution for group: ('42024', 'afternoon_sat')
# Evaluating distribution for group: ('42025', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42025', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42025', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42025', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42025', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42025', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42025', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42025', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42026', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42026', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42026', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42026', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42026', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42026', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42026', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42026', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42027', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42027', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42027', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42027', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42027', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42027', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42027', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42027', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42028', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42028', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42028', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42028', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42028', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42028', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42028', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42028', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42029', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42029', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42029', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42029', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42029', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42029', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42029', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42029', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42030', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42030', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42030', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42030', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42030', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42030', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42030', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42030', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42031', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42031', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42031', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42031', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42031', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42031', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42031', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42031', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42032', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42032', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42032', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42032', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42032', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42032', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42032', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42032', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42034', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42034', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42034', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42034', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42034', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42034', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42034', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42034', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42036', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42036', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42036', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42036', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42036', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42036', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42036', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42036', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42038', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42038', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42038', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42038', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42038', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42038', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42038', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42038', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42040', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42040', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42040', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42040', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42040', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42040', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42040', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42040', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42043', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42043', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42043', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42043', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42043', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42043', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42043', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42043', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42044', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42044', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42044', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42044', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42044', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42044', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42044', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42044', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42045', 'night')
# Evaluating distribution for group: ('42045', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42045', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42045', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42045', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42045', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42045', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42045', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42050', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42050', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42050', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42050', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42050', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42050', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42050', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# ...
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42095', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42095', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42095', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42095', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42100', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42100', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42100', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42100', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42100', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42100', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42100', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42100', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42101', 'night')
# Evaluating distribution for group: ('42101', 'morning')
# Evaluating distribution for group: ('42101', 'lunch')
# Evaluating distribution for group: ('42101', 'morning_sat')
# Evaluating distribution for group: ('42101', 'afternoon')
# Evaluating distribution for group: ('42101', 'evening')
# Evaluating distribution for group: ('42101', 'sunday')
# Evaluating distribution for group: ('42101', 'afternoon_sat')
# Evaluating distribution for group: ('42102', 'night')
# Evaluating distribution for group: ('42102', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42102', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42102', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42102', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42102', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42102', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42102', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42103', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42103', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42103', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42103', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42103', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42103', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42103', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42104', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42104', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42104', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42104', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42104', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42104', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42104', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42104', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42105', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42105', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42105', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42105', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42105', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42105', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42105', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42105', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42106', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42106', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42106', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42106', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42106', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42106', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42106', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42106', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42107', 'night')
# Evaluating distribution for group: ('42107', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42107', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42107', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42107', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42107', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42107', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42107', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42108', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42108', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42108', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42108', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42108', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42108', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42108', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42108', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42109', 'night')
# Evaluating distribution for group: ('42109', 'morning')
# Evaluating distribution for group: ('42109', 'lunch')
# Evaluating distribution for group: ('42109', 'morning_sat')
# Evaluating distribution for group: ('42109', 'afternoon')
# Evaluating distribution for group: ('42109', 'evening')
# Evaluating distribution for group: ('42109', 'sunday')
# Evaluating distribution for group: ('42109', 'afternoon_sat')
# Evaluating distribution for group: ('42116', 'night')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42116', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42116', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42116', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42116', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42116', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42116', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42116', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42240', 'night')
# Evaluating distribution for group: ('42240', 'morning')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42240', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42240', 'morning_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42240', 'afternoon')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42240', 'evening')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42240', 'sunday')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42240', 'afternoon_sat')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('42241', 'night')
# Evaluating distribution for group: ('42241', 'morning')
# Evaluating distribution for group: ('42241', 'lunch')
# Evaluating distribution for group: ('42241', 'morning_sat')
# Evaluating distribution for group: ('42241', 'afternoon')
# Evaluating distribution for group: ('42241', 'evening')
# Evaluating distribution for group: ('42241', 'sunday')
# Evaluating distribution for group: ('42241', 'afternoon_sat')
# Evaluating distribution for group: ('987654321', 'morning')
# Evaluating distribution for group: ('987654321', 'lunch')
# No valid data for lognormal distribution.
# No valid data for gamma distribution.
# No valid data for beta distribution.
# Evaluating distribution for group: ('987654321', 'afternoon')
# Evaluating distribution for group: ('987654321', 'afternoon_sat')
# Lognormal distribution is the best fit.

# %%
def fill_missing_with_lognormal(group):
    # Filter out missing values
    observed_data = group.dropna()
    
    if len(observed_data) < 2:
        # Not enough data to fit a distribution
        return group
    
    # Fit a lognormal distribution to the observed data
    sigma, loc, scale = lognorm.fit(observed_data)
    
    # Generate random samples from the fitted distribution
    num_missing = group.isnull().sum()
    generated_samples = lognorm.rvs(sigma, loc=loc, scale=scale, size=num_missing)
    
    # Replace missing values with generated samples
    group[group.isnull()] = generated_samples
    
    return group

# Apply the function to each group defined by ('Zonkod', 'Tidpunkt')
combined_df_filled = combined_df.groupby(['Zonkod', 'Tidpunkt']).apply(fill_missing_with_lognormal)
combined_df.head()
# Out:
#   Zonkod  Tid_i_minuter               Start               Stopp  Belopp  \
# 0  42040     836.700000 2023-11-30 10:07:18 2023-12-01 00:04:00   59.42
# 1  42036     414.250000 2023-11-30 17:25:45 2023-12-01 00:20:00   11.67
# 2  42004     439.366667 2023-11-30 17:06:20 2023-12-01 00:25:42   10.80
# 3  42027       0.166667 2023-12-01 00:34:08 2023-12-01 00:34:18    0.00
# 4  42029       1.583333 2023-12-01 00:50:13 2023-12-01 00:51:48    0.00
#
#      Source        Parkeringsomrade Transaktions_ID  P-avgift_exkl._Moms  \
# 0  EasyPark  Idrottens hus/Ishallen      1528524158               47.536
# 1  EasyPark              Hamntorget      1529472222                9.336
# 2  EasyPark            Billeplatsen      1529431361                8.640
# 3  EasyPark                 GA Torg      1529752222                0.000
# 4  EasyPark         Gasverksgatan B      1529752960                0.000
#
#    P-avgift_Moms  ...  Registreringsnummer          Kontrakt  Status  \
# 0         11.884  ...               UGR040  PO-442-Base rule     NaN
# 1          2.334  ...               DGJ970  PO-442-Base rule     NaN
# 2          2.160  ...               BFY883  PO-442-Base rule     NaN
# 3          0.000  ...               OZR297  PO-442-Base rule     NaN
# 4          0.000  ...               YFO272  PO-442-Base rule     NaN
#
#    Biljettyp  Terminal_ID Betalenhet_Namn  Nod Maskat_PAN Biljettnummer  \
# 0        NaN          NaN             NaN  NaN        NaN           NaN
# 1        NaN          NaN             NaN  NaN        NaN           NaN
# 2        NaN          NaN             NaN  NaN        NaN           NaN
# 3        NaN          NaN             NaN  NaN        NaN           NaN
# 4        NaN          NaN             NaN  NaN        NaN           NaN
#
#     Tidpunkt
# 0      lunch
# 1  afternoon
# 2  afternoon
# 3      night
# 4      night
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Filling each time group missing values with random values based on standard deviation in this group

# %%
# # Define a function to fill missing values with random numbers based on standard deviation within each group
# def fill_missing_with_random(df, group_columns, value_column):
#     # Calculate standard deviation for each group
#     std_by_group = df.groupby(group_columns)[value_column].std()
    
#     # Iterate over each group
#     for group, std in std_by_group.items():
#         # Get the indices of missing values within the group
#         missing_indices = df[(df[group_columns[0]] == group[0]) & (df[group_columns[1]] == group[1]) & df[value_column].isnull()].index
        
#         # Generate random numbers based on the standard deviation of the group
#         random_values = np.random.normal(loc=df[(df[group_columns[0]] == group[0]) & (df[group_columns[1]] == group[1])][value_column].mean(), 
#                                          scale=std,
#                                          size=len(missing_indices))
#         # Replace missing values with random numbers within the group
#         df.loc[missing_indices, value_column] = random_values

# # Fill missing values with random numbers based on standard deviation within each group
# fill_missing_with_random(combined_df, ['Zonkod', 'Tidpunkt'], 'Tid_i_minuter')

# %% [markdown]
# #### Creating column for the type of parking

# %%
# Define the conditions for each category
conditions = [
    (combined_df['Tid_i_minuter'] <= 4320),
    (combined_df['Tid_i_minuter'] > 4320) & (combined_df['Tid_i_minuter'] <= 10080),
    (combined_df['Tid_i_minuter'] > 10080)
]

# Define the corresponding values for each category
categories = ['Short_term', 'Week', 'Long_term']

# Create the new column 'Park_type' based on the conditions and values
combined_df['Park_type'] = np.select(conditions, categories)

combined_df = combined_df.reindex(columns=['Zonkod', 'Tid_i_minuter', 'Start', 'Stopp', 'Belopp', 'Park_type','Tidpunkt', 'Day', 'Month', 'Source',
       'Parkeringsomrade', 'Transaktions_ID', 'P-avgift_exkl._Moms',
       'P-avgift_Moms', 'P-avgift_inkl._Moms', 'Arvode_%', 'Arvode_exkl._Moms',
       'Arvode_Moms', 'Arvode_inkl._Moms', 'Registreringsnummer', 'Kontrakt',
       'Status', 'Biljettyp', 'Terminal_ID', 'Betalenhet_Namn', 'Nod',
       'Maskat_PAN', 'Biljettnummer'])


# Display the DataFrame to verify the changes
combined_df.head()
# Out:
#   Zonkod  Tid_i_minuter               Start               Stopp  Belopp  \
# 0  42040     836.700000 2023-11-30 10:07:18 2023-12-01 00:04:00   59.42
# 1  42036     414.250000 2023-11-30 17:25:45 2023-12-01 00:20:00   11.67
# 2  42004     439.366667 2023-11-30 17:06:20 2023-12-01 00:25:42   10.80
# 3  42027       0.166667 2023-12-01 00:34:08 2023-12-01 00:34:18    0.00
# 4  42029       1.583333 2023-12-01 00:50:13 2023-12-01 00:51:48    0.00
#
#     Park_type   Tidpunkt       Day     Month    Source  ... Arvode_inkl._Moms  \
# 0  Short_term      lunch  Thursday  November  EasyPark  ...               0.0
# 1  Short_term  afternoon  Thursday  November  EasyPark  ...               0.0
# 2  Short_term  afternoon  Thursday  November  EasyPark  ...               0.0
# 3  Short_term      night    Friday  December  EasyPark  ...               0.0
# 4  Short_term      night    Friday  December  EasyPark  ...               0.0
#
#   Registreringsnummer          Kontrakt  Status  Biljettyp  Terminal_ID  \
# 0              UGR040  PO-442-Base rule     NaN        NaN          NaN
# 1              DGJ970  PO-442-Base rule     NaN        NaN          NaN
# 2              BFY883  PO-442-Base rule     NaN        NaN          NaN
# 3              OZR297  PO-442-Base rule     NaN        NaN          NaN
# 4              YFO272  PO-442-Base rule     NaN        NaN          NaN
#
#    Betalenhet_Namn  Nod  Maskat_PAN Biljettnummer
# 0              NaN  NaN         NaN           NaN
# 1              NaN  NaN         NaN           NaN
# 2              NaN  NaN         NaN           NaN
# 3              NaN  NaN         NaN           NaN
# 4              NaN  NaN         NaN           NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Showing the number of purchases per Month

# %%
# Define the order of months
month_order = ['February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December', 'January']

# Convert 'Month' column to categorical data with the specified order
combined_df['Month'] = pd.Categorical(combined_df['Month'], categories=month_order, ordered=True)

# Calculate parking purchases by month
parking_counts = combined_df['Month'].value_counts()

# Sort the counts by month order
parking_counts = parking_counts.sort_index()

# Create a line plot
sns.lineplot(data=parking_counts)

# Set plot labels and title
plt.xlabel('Month')
plt.ylabel('Number of Parking Purchases')
plt.title('Parking Purchases by Month')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Showing the number of purchases per weekday

# %%
# Define the order of months
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Convert 'Month' column to categorical data with the specified order
combined_df['Day'] = pd.Categorical(combined_df['Day'], categories=day_order, ordered=True)

# Calculate parking purchases by day
parking_counts_1 = combined_df['Day'].value_counts()

# Sort the counts by month order
parking_counts_1 = parking_counts_1.sort_index()

# Create a line plot
sns.lineplot(data=parking_counts_1)

# Set plot labels and title
plt.xlabel('Day')
plt.ylabel('Number of Parking Purchases')
plt.title('Parking Purchases by Day')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Average parking time by Month

# %%
# Calculate average 'Tid_i_minuter' by month
avg_tid_i_minuter = combined_df.groupby('Month')['Tid_i_minuter'].mean().reset_index()

# Define the order of months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

# Convert 'Month' column to categorical data with the specified order
avg_tid_i_minuter['Month'] = pd.Categorical(avg_tid_i_minuter['Month'], categories=month_order, ordered=True)

# Create a bar plot for average 'Tid_i_minuter' by month
sns.barplot(data=avg_tid_i_minuter, x='Month', y='Tid_i_minuter')

# Set plot labels and title
plt.xlabel('Month')
plt.ylabel('Average Parking time')
plt.title('Average Parking time by Month')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Sum of parking time by Month

# %%
# Group the DataFrame by 'Month' and calculate the sum of 'Tid_i_minuter'
sum_tid_i_minuter_by_month = combined_df.groupby('Month')['Tid_i_minuter'].sum().reset_index()

# Define the order of months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

# Create a bar plot for average 'Tid_i_minuter' by month
sns.barplot(data=sum_tid_i_minuter_by_month, x='Month', y='Tid_i_minuter')

# Set plot labels and title
plt.xlabel('Month')
plt.ylabel('Sum of parking time')
plt.title('Sum of parking time by Month')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Number purchases of week parking by Zonkod

# %%
# Filter the DataFrame for 'Tid_i_minuter' values from 4320 to 10080
filtered_df = combined_df[combined_df['Park_type'] == 'Week']

# Count the number of purchases by 'Zonkod'
purchases_by_zonkod = filtered_df['Zonkod'].value_counts().reset_index()
purchases_by_zonkod.columns = ['Zonkod', 'Number of Purchases']

# Create a bar plot for number of purchases by Zonkod
sns.barplot(data=purchases_by_zonkod, x='Zonkod', y='Number of Purchases')

# Set plot labels and title
plt.xlabel('Zonkod')
plt.ylabel('Number of Purchases')
plt.title('Week Parking')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Number purchases of long-term parking by Zonkod

# %%
# Filter the DataFrame for 'Tid_i_minuter' values from 4320 to 10080
filtered_df_ = combined_df[combined_df['Park_type'] == 'Long_term']

# Count the number of purchases by 'Zonkod'
purchases_by_zonkod = filtered_df_['Zonkod'].value_counts().reset_index()
purchases_by_zonkod.columns = ['Zonkod', 'Number of Purchases']

# Create a bar plot for number of purchases by Zonkod
sns.barplot(data=purchases_by_zonkod, x='Zonkod', y='Number of Purchases')

# Set plot labels and title
plt.xlabel('Zonkod')
plt.ylabel('Number of Purchases')
plt.title('Long_term parking')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Showing short-term parking, numbers of purchases

# %%
# Filter the DataFrame for 'Short_term' category in 'Park_type' column
short_term_data = combined_df[combined_df['Park_type'] == 'Short_term']

# Count the number of purchases for each 'Zonkod'
short_term_counts = short_term_data['Zonkod'].value_counts()

# Plot the bar chart
plt.figure(figsize=(12, 8))  # Adjust figure size if needed
sns.barplot(x=short_term_counts.index, y=short_term_counts.values)

# Set plot labels and title
plt.xlabel('Zonkod')
plt.ylabel('Number of Short_term Purchases')
plt.title('Short_term parking purchases by Zonkod')
plt.xticks(rotation=90, ha='center', va='top')  # Rotate x-axis labels vertically
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# #### Top 10 short-term

# %%
# Count the number of short-term purchases for each Zonkod
short_term_counts = short_term_data['Zonkod'].value_counts()

# Sort the Zonkods by the number of short-term purchases and select the top 10
top_10_zonkods = short_term_counts.sort_values(ascending=False).head(10)

# Plot the bar chart for the top 10 Zonkods
plt.figure(figsize=(12, 8))  # Adjust figure size if needed
sns.barplot(x=top_10_zonkods.index, y=top_10_zonkods.values)

# Set plot labels and title
plt.xlabel('Zonkod')
plt.ylabel('Number of Short-term Purchases')
plt.title('Top 10 Zonkods for Short-term Parking Purchases')
plt.xticks(rotation=90, ha='center', va='top')  # Rotate x-axis labels vertically
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
park_types = combined_df['Park_type'].unique()
print(park_types)
# Out:
# ['Short_term' 'Week' 'Long_term' '0']

# %% [markdown]
# #### Showing the number of purchases for Week and Long-term

# %%
# Filter the DataFrame for 'Week' and 'Long_term' categories
filtered_combined_df = combined_df[combined_df['Park_type'].isin(['Week', 'Long_term'])]

# Group the filtered DataFrame by 'Zonkod' and count the number of observations in each group
purchase_counts = filtered_combined_df.groupby(['Zonkod', 'Park_type']).size().unstack(fill_value=0)

# Create a stacked bar chart
ax = purchase_counts.plot(kind='bar', stacked=True, colormap='Pastel2')

# Set plot labels and title
plt.xlabel('Zonkod')
plt.ylabel('Number of Purchases')
plt.title('Parking Purchases by Week and Long-term Categories')

# Create a legend with labels from purchase_counts columns
legend_labels = purchase_counts.columns.tolist()
plt.legend(legend_labels, title='Parking Category')

plt.tight_layout()
plt.show()
